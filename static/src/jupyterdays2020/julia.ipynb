# %% [markdown]
# # Let's be full of "originality" and plot ... some Covid data (sorry)

# %% [markdown]
# ## Load packages

# %%
using CSV
using DataFrames
using Dates
using TimeSeries
using Plots
gr();

# %% [markdown]
# ## Read data into an array of data frames

# %% [markdown]
# We will use the dataset compiled by the [Center for Systems Science and Engineering (CSSE) at JHU](https://systems.jhu.edu/) and [available on GitHub](https://github.com/CSSEGISandData/COVID-19).
#
# You can clone this repository and find the `.csv` files under `COVID-19/csse_covid_19_data/csse_covid_19_time_series/`

# %%
conf_file = "/home/marie/parvus/pwg/wtm/tjl/static/data/covid/" *
    "csse_covid_19_data/csse_covid_19_time_series/" *
    "time_series_covid19_confirmed_global.csv"

dead_file = "/home/marie/parvus/pwg/wtm/tjl/static/data/covid/" *
    "csse_covid_19_data/csse_covid_19_time_series/" *
    "time_series_covid19_deaths_global.csv"

dat = DataFrame.(CSV.File.([conf_file, dead_file]))
# Out:
# 2-element Array{DataFrame,1}:
#  266×207 DataFrame. Omitted printing of 204 columns
# │ Row │ Province/State                   │ Country/Region        │ Lat      │
# │     │ Union{Missing, String}           │ String                │ Float64  │
# ├─────┼──────────────────────────────────┼───────────────────────┼──────────┤
# │ 1   │ missing                          │ Afghanistan           │ 33.9391  │
# │ 2   │ missing                          │ Albania               │ 41.1533  │
# │ 3   │ missing                          │ Algeria               │ 28.0339  │
# │ 4   │ missing                          │ Andorra               │ 42.5063  │
# │ 5   │ missing                          │ Angola                │ -11.2027 │
# │ 6   │ missing                          │ Antigua and Barbuda   │ 17.0608  │
# │ 7   │ missing                          │ Argentina             │ -38.4161 │
# │ 8   │ missing                          │ Armenia               │ 40.0691  │
# │ 9   │ Australian Capital Territory     │ Australia             │ -35.4735 │
# │ 10  │ New South Wales                  │ Australia             │ -33.8688 │
# ⋮
# │ 256 │ Bonaire, Sint Eustatius and Saba │ Netherlands           │ 12.1784  │
# │ 257 │ missing                          │ Malawi                │ -13.2543 │
# │ 258 │ Falkland Islands (Malvinas)      │ United Kingdom        │ -51.7963 │
# │ 259 │ Saint Pierre and Miquelon        │ France                │ 46.8852  │
# │ 260 │ missing                          │ South Sudan           │ 6.877    │
# │ 261 │ missing                          │ Western Sahara        │ 24.2155  │
# │ 262 │ missing                          │ Sao Tome and Principe │ 0.1864   │
# │ 263 │ missing                          │ Yemen                 │ 15.5527  │
# │ 264 │ missing                          │ Comoros               │ -11.6455 │
# │ 265 │ missing                          │ Tajikistan            │ 38.861   │
# │ 266 │ missing                          │ Lesotho               │ -29.61   │
#  266×207 DataFrame. Omitted printing of 204 columns
# │ Row │ Province/State                   │ Country/Region        │ Lat      │
# │     │ Union{Missing, String}           │ String                │ Float64  │
# ├─────┼──────────────────────────────────┼───────────────────────┼──────────┤
# │ 1   │ missing                          │ Afghanistan           │ 33.9391  │
# │ 2   │ missing                          │ Albania               │ 41.1533  │
# │ 3   │ missing                          │ Algeria               │ 28.0339  │
# │ 4   │ missing                          │ Andorra               │ 42.5063  │
# │ 5   │ missing                          │ Angola                │ -11.2027 │
# │ 6   │ missing                          │ Antigua and Barbuda   │ 17.0608  │
# │ 7   │ missing                          │ Argentina             │ -38.4161 │
# │ 8   │ missing                          │ Armenia               │ 40.0691  │
# │ 9   │ Australian Capital Territory     │ Australia             │ -35.4735 │
# │ 10  │ New South Wales                  │ Australia             │ -33.8688 │
# ⋮
# │ 256 │ Bonaire, Sint Eustatius and Saba │ Netherlands           │ 12.1784  │
# │ 257 │ missing                          │ Malawi                │ -13.2543 │
# │ 258 │ Falkland Islands (Malvinas)      │ United Kingdom        │ -51.7963 │
# │ 259 │ Saint Pierre and Miquelon        │ France                │ 46.8852  │
# │ 260 │ missing                          │ South Sudan           │ 6.877    │
# │ 261 │ missing                          │ Western Sahara        │ 24.2155  │
# │ 262 │ missing                          │ Sao Tome and Principe │ 0.1864   │
# │ 263 │ missing                          │ Yemen                 │ 15.5527  │
# │ 264 │ missing                          │ Comoros               │ -11.6455 │
# │ 265 │ missing                          │ Tajikistan            │ 38.861   │
# │ 266 │ missing                          │ Lesotho               │ -29.61   │

# %% [markdown]
# ## Transform to a single data frame in long format

# %%
DataFrames.rename!.(dat, Dict.(1 => Symbol("province"),
                               2 => Symbol("country")))

var = ["confirmed", "dead"];

datlong = map((x, y) -> stack(x, Not(collect(1:4)),
                              variable_name = Symbol("date"),
                              value_name = Symbol("$y")),
              dat, var)

all = innerjoin(datlong[1], datlong[2],
                on = [:date, :country, :province, :Lat, :Long],
                makeunique = false, validate = (false, false))

select!(all, [5, 2, 1, 6, 7])

all.date = Date.(replace.(string.(all.date),
                          r"(.*)(..)$" => s"\g<1>20\2"), "m/dd/yy");

all
# Out:
# 53998×5 DataFrame. Omitted printing of 3 columns
# │ Row   │ date       │ country               │
# │       │ Date       │ String                │
# ├───────┼────────────┼───────────────────────┤
# │ 1     │ 2020-01-22 │ Afghanistan           │
# │ 2     │ 2020-01-22 │ Albania               │
# │ 3     │ 2020-01-22 │ Algeria               │
# │ 4     │ 2020-01-22 │ Andorra               │
# │ 5     │ 2020-01-22 │ Angola                │
# │ 6     │ 2020-01-22 │ Antigua and Barbuda   │
# │ 7     │ 2020-01-22 │ Argentina             │
# │ 8     │ 2020-01-22 │ Armenia               │
# │ 9     │ 2020-01-22 │ Australia             │
# │ 10    │ 2020-01-22 │ Australia             │
# ⋮
# │ 53988 │ 2020-08-11 │ Netherlands           │
# │ 53989 │ 2020-08-11 │ Malawi                │
# │ 53990 │ 2020-08-11 │ United Kingdom        │
# │ 53991 │ 2020-08-11 │ France                │
# │ 53992 │ 2020-08-11 │ South Sudan           │
# │ 53993 │ 2020-08-11 │ Western Sahara        │
# │ 53994 │ 2020-08-11 │ Sao Tome and Principe │
# │ 53995 │ 2020-08-11 │ Yemen                 │
# │ 53996 │ 2020-08-11 │ Comoros               │
# │ 53997 │ 2020-08-11 │ Tajikistan            │
# │ 53998 │ 2020-08-11 │ Lesotho               │

# %% [markdown]
# ## World summary

# %%
world = combine(groupby(all, :date),
                :confirmed => sum => :confirmed,
                :dead => sum => :dead)
# Out:
# 203×3 DataFrame
# │ Row │ date       │ confirmed │ dead   │
# │     │ Date       │ Int64     │ Int64  │
# ├─────┼────────────┼───────────┼────────┤
# │ 1   │ 2020-01-22 │ 555       │ 17     │
# │ 2   │ 2020-01-23 │ 654       │ 18     │
# │ 3   │ 2020-01-24 │ 941       │ 26     │
# │ 4   │ 2020-01-25 │ 1434      │ 42     │
# │ 5   │ 2020-01-26 │ 2118      │ 56     │
# │ 6   │ 2020-01-27 │ 2927      │ 82     │
# │ 7   │ 2020-01-28 │ 5578      │ 131    │
# │ 8   │ 2020-01-29 │ 6166      │ 133    │
# │ 9   │ 2020-01-30 │ 8234      │ 171    │
# │ 10  │ 2020-01-31 │ 9927      │ 213    │
# ⋮
# │ 193 │ 2020-08-01 │ 17850617  │ 685773 │
# │ 194 │ 2020-08-02 │ 18079723  │ 690065 │
# │ 195 │ 2020-08-03 │ 18282208  │ 694396 │
# │ 196 │ 2020-08-04 │ 18540789  │ 701347 │
# │ 197 │ 2020-08-05 │ 18811953  │ 708424 │
# │ 198 │ 2020-08-06 │ 19097149  │ 714940 │
# │ 199 │ 2020-08-07 │ 19378036  │ 721324 │
# │ 200 │ 2020-08-08 │ 19637506  │ 726781 │
# │ 201 │ 2020-08-09 │ 19861683  │ 731326 │
# │ 202 │ 2020-08-10 │ 20089624  │ 736191 │
# │ 203 │ 2020-08-11 │ 20344188  │ 742700 │

# %%
plot(TimeArray(world, timestamp = :date),
     title = "World", legend = :outertopright)

# %% [markdown]
# ## A few selected countries

# %% [markdown]
# ### Select the data for the chosen countries

# %%
canada = all[all.country .== "Canada", :]
canada = combine(groupby(canada, :date),
                 :confirmed => sum => :canada_conf,
                 :dead => sum => :canada_dead)

us = all[all.country .== "US", :]
select!(us, Not([2, 3]))
DataFrames.rename!(us, :confirmed => :us_conf, :dead => :us_dead)

mexico = all[all.country .== "Mexico", :]
select!(mexico, Not([2, 3]))
DataFrames.rename!(mexico, :confirmed => :mexico_conf, :dead => :mexico_dead)

france = all[all.country .== "France", :]
france = combine(groupby(france, :date),
                 :confirmed => sum => :france_conf,
                 :dead => sum => :france_dead)
                 
countries = innerjoin(canada, us, mexico, france,
                      on = :date, makeunique = false,
                      validate = (false, false))
# Out:
# 203×9 DataFrame. Omitted printing of 4 columns
# │ Row │ date       │ canada_conf │ canada_dead │ us_conf │ us_dead │
# │     │ Date       │ Int64       │ Int64       │ Int64   │ Int64   │
# ├─────┼────────────┼─────────────┼─────────────┼─────────┼─────────┤
# │ 1   │ 2020-01-22 │ 0           │ 0           │ 1       │ 0       │
# │ 2   │ 2020-01-23 │ 0           │ 0           │ 1       │ 0       │
# │ 3   │ 2020-01-24 │ 0           │ 0           │ 2       │ 0       │
# │ 4   │ 2020-01-25 │ 0           │ 0           │ 2       │ 0       │
# │ 5   │ 2020-01-26 │ 1           │ 0           │ 5       │ 0       │
# │ 6   │ 2020-01-27 │ 1           │ 0           │ 5       │ 0       │
# │ 7   │ 2020-01-28 │ 2           │ 0           │ 5       │ 0       │
# │ 8   │ 2020-01-29 │ 2           │ 0           │ 5       │ 0       │
# │ 9   │ 2020-01-30 │ 2           │ 0           │ 5       │ 0       │
# │ 10  │ 2020-01-31 │ 4           │ 0           │ 7       │ 0       │
# ⋮
# │ 193 │ 2020-08-01 │ 118523      │ 8986        │ 4620592 │ 155159  │
# │ 194 │ 2020-08-02 │ 118768      │ 8990        │ 4668172 │ 155565  │
# │ 195 │ 2020-08-03 │ 118973      │ 8995        │ 4713540 │ 156104  │
# │ 196 │ 2020-08-04 │ 119659      │ 9005        │ 4771080 │ 157482  │
# │ 197 │ 2020-08-05 │ 120033      │ 9010        │ 4823890 │ 158854  │
# │ 198 │ 2020-08-06 │ 120387      │ 9013        │ 4883582 │ 160104  │
# │ 199 │ 2020-08-07 │ 120903      │ 9017        │ 4941755 │ 161347  │
# │ 200 │ 2020-08-08 │ 121148      │ 9024        │ 4997929 │ 162423  │
# │ 201 │ 2020-08-09 │ 121367      │ 9028        │ 5044864 │ 162938  │
# │ 202 │ 2020-08-10 │ 122053      │ 9034        │ 5094400 │ 163463  │
# │ 203 │ 2020-08-11 │ 122389      │ 9038        │ 5141208 │ 164527  │

# %% [markdown]
# ### Select and plot confirmed cases

# %%
confirmed = select(countries, [1, 2, 4, 6, 8])
DataFrames.rename!(confirmed, replace.(names(confirmed), r"_conf" => s""))
# Out:
# 203×5 DataFrame
# │ Row │ date       │ canada │ us      │ mexico │ france │
# │     │ Date       │ Int64  │ Int64   │ Int64  │ Int64  │
# ├─────┼────────────┼────────┼─────────┼────────┼────────┤
# │ 1   │ 2020-01-22 │ 0      │ 1       │ 0      │ 0      │
# │ 2   │ 2020-01-23 │ 0      │ 1       │ 0      │ 0      │
# │ 3   │ 2020-01-24 │ 0      │ 2       │ 0      │ 2      │
# │ 4   │ 2020-01-25 │ 0      │ 2       │ 0      │ 3      │
# │ 5   │ 2020-01-26 │ 1      │ 5       │ 0      │ 3      │
# │ 6   │ 2020-01-27 │ 1      │ 5       │ 0      │ 3      │
# │ 7   │ 2020-01-28 │ 2      │ 5       │ 0      │ 4      │
# │ 8   │ 2020-01-29 │ 2      │ 5       │ 0      │ 5      │
# │ 9   │ 2020-01-30 │ 2      │ 5       │ 0      │ 5      │
# │ 10  │ 2020-01-31 │ 4      │ 7       │ 0      │ 5      │
# ⋮
# │ 193 │ 2020-08-01 │ 118523 │ 4620592 │ 434193 │ 225198 │
# │ 194 │ 2020-08-02 │ 118768 │ 4668172 │ 439046 │ 225198 │
# │ 195 │ 2020-08-03 │ 118973 │ 4713540 │ 443813 │ 225198 │
# │ 196 │ 2020-08-04 │ 119659 │ 4771080 │ 449961 │ 228576 │
# │ 197 │ 2020-08-05 │ 120033 │ 4823890 │ 456100 │ 228576 │
# │ 198 │ 2020-08-06 │ 120387 │ 4883582 │ 462690 │ 231310 │
# │ 199 │ 2020-08-07 │ 120903 │ 4941755 │ 469407 │ 235207 │
# │ 200 │ 2020-08-08 │ 121148 │ 4997929 │ 475902 │ 235208 │
# │ 201 │ 2020-08-09 │ 121367 │ 5044864 │ 480278 │ 235237 │
# │ 202 │ 2020-08-10 │ 122053 │ 5094400 │ 485836 │ 239349 │
# │ 203 │ 2020-08-11 │ 122389 │ 5141208 │ 492522 │ 239355 │

# %%
plot(TimeArray(confirmed, timestamp = :date),
     title = "Confirmed cases", legend = :outertopright)

# %% [markdown]
# ### Select and plot death cases

# %%
dead = select(countries, [1, 3, 5, 7, 9])
DataFrames.rename!(dead, replace.(names(dead), r"_dead" => s""))
# Out:
# 203×5 DataFrame
# │ Row │ date       │ canada │ us     │ mexico │ france │
# │     │ Date       │ Int64  │ Int64  │ Int64  │ Int64  │
# ├─────┼────────────┼────────┼────────┼────────┼────────┤
# │ 1   │ 2020-01-22 │ 0      │ 0      │ 0      │ 0      │
# │ 2   │ 2020-01-23 │ 0      │ 0      │ 0      │ 0      │
# │ 3   │ 2020-01-24 │ 0      │ 0      │ 0      │ 0      │
# │ 4   │ 2020-01-25 │ 0      │ 0      │ 0      │ 0      │
# │ 5   │ 2020-01-26 │ 0      │ 0      │ 0      │ 0      │
# │ 6   │ 2020-01-27 │ 0      │ 0      │ 0      │ 0      │
# │ 7   │ 2020-01-28 │ 0      │ 0      │ 0      │ 0      │
# │ 8   │ 2020-01-29 │ 0      │ 0      │ 0      │ 0      │
# │ 9   │ 2020-01-30 │ 0      │ 0      │ 0      │ 0      │
# │ 10  │ 2020-01-31 │ 0      │ 0      │ 0      │ 0      │
# ⋮
# │ 193 │ 2020-08-01 │ 8986   │ 155159 │ 47472  │ 30268  │
# │ 194 │ 2020-08-02 │ 8990   │ 155565 │ 47746  │ 30268  │
# │ 195 │ 2020-08-03 │ 8995   │ 156104 │ 48012  │ 30268  │
# │ 196 │ 2020-08-04 │ 9005   │ 157482 │ 48869  │ 30297  │
# │ 197 │ 2020-08-05 │ 9010   │ 158854 │ 49698  │ 30297  │
# │ 198 │ 2020-08-06 │ 9013   │ 160104 │ 50517  │ 30308  │
# │ 199 │ 2020-08-07 │ 9017   │ 161347 │ 51311  │ 30327  │
# │ 200 │ 2020-08-08 │ 9024   │ 162423 │ 52006  │ 30327  │
# │ 201 │ 2020-08-09 │ 9028   │ 162938 │ 52298  │ 30327  │
# │ 202 │ 2020-08-10 │ 9034   │ 163463 │ 53003  │ 30327  │
# │ 203 │ 2020-08-11 │ 9038   │ 164527 │ 53929  │ 30328  │

# %%
plot(TimeArray(dead, timestamp = :date),
     title = "Deaths", legend = :outertopright)
